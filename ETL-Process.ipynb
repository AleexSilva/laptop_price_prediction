# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
laptop = pd.read_csv('./data/laptop_price.csv', encoding='latin-1')
df = pd.read_csv('./data/laptops.csv')

# %%
laptop
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
laptop.OpSys.value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
laptop.Product.value_counts()
# Out:
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: Product, Length: 618, dtype: int64

# %%
laptop.TypeName.value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
laptop.Ram.value_counts()
# Out:
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: Ram, dtype: int64

# %%
laptop['Ram-GB'] = laptop['Ram'].str.strip('GB')
laptop['Weight-KG'] = laptop['Weight'].str.strip('kg')
laptop=laptop.drop(columns={'Ram','Weight'},axis=1)
laptop.head(10)
# Out:
#    laptop_ID Company          Product   TypeName  Inches  \
# 0          1   Apple      MacBook Pro  Ultrabook    13.3
# 1          2   Apple      Macbook Air  Ultrabook    13.3
# 2          3      HP           250 G6   Notebook    15.6
# 3          4   Apple      MacBook Pro  Ultrabook    15.4
# 4          5   Apple      MacBook Pro  Ultrabook    13.3
# 5          6    Acer         Aspire 3   Notebook    15.6
# 6          7   Apple      MacBook Pro  Ultrabook    15.4
# 7          8   Apple      Macbook Air  Ultrabook    13.3
# 8          9    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9         10    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu  Memory  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz     128
# 1                            1440x900        Intel Core i5 1.8GHz     128
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz     256
# ...

# %%
laptop['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
laptop.OpSys.value_counts()
# Out:
# Windows 10    1080
# No OS           66
# Linux           62
# Windows 7       45
# Chrome OS       27
# macOS           21
# Android          2
# Name: OpSys, dtype: int64

# %%
laptop.OpSys.replace({'Windows 10 S':'Windows 10','Mac OS X':'macOS'},inplace=True)

# %%
(
    laptop.Memory.str[0:3].value_counts()
)
# Out:
# 256    508
# 1TB    240
# 128    177
# 512    140
# 500    132
# 32G     45
# 64G     17
# 2TB     16
# 1.0     10
# 16G     10
# 180      5
# 240      1
# 8GB      1
# 508      1
# Name: Memory, dtype: int64

# %%
laptop['memory-GB']=(
    laptop.Memory.str[0:3]
    .str.replace('TB','000')
    .str.strip('G')
    .str.strip('.0')
    .str.strip('GB')
).astype(int)

# %%
laptop
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
(laptop.Memory.str[-3:]
 .str.replace('age','Flash Storage')
 
 ).value_counts()
# Out:
# SSD    641
# HDD    576
# age     74
# rid     12
# Name: Memory, dtype: int64

# %%
laptop.Memory.value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
new_table=(
    laptop['Memory']
    .str.split(' ',expand=True)
)
new_table
# Out:
#           0      1        2     3     4     5     6
# 0     128GB    SSD     None  None  None  None  None
# 1     128GB  Flash  Storage  None  None  None  None
# 2     256GB    SSD     None  None  None  None  None
# 3     512GB    SSD     None  None  None  None  None
# 4     256GB    SSD     None  None  None  None  None
# ...     ...    ...      ...   ...   ...   ...   ...
# 1298  128GB    SSD     None  None  None  None  None
# 1299  512GB    SSD     None  None  None  None  None
# 1300   64GB  Flash  Storage  None  None  None  None
# 1301    1TB    HDD     None  None  None  None  None
# 1302  500GB    HDD     None  None  None  None  None
#
# [1303 rows x 7 columns]

# %%
new_table[2]
# Out:
# 0          None
# 1       Storage
# 2          None
# 3          None
# 4          None
#          ...
# 1298       None
# 1299       None
# 1300    Storage
# 1301       None
# 1302       None
# Name: 2, Length: 1303, dtype: object

# %%
new_table['RAM-GB']=(

new_table[0]
    .str.strip('TB')
    .str.strip('G')
    .str.strip('.0')
    .str.strip('GB')
    .astype(int)
)

# %%
laptop['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
new_table['RAM-GB'].replace([5,500],inplace=True)
new_table['RAM-GB'].replace([1,1000],inplace=True)
new_table['RAM-GB'].replace([2,2000],inplace=True)

# %%
new_table['RAM-GB'].value_counts()
# Out:
# 256    730
# 128    262
# 512    199
# 32      66
# 64      24
# 16      13
# 18       6
# 24       1
# 8        1
# 508      1
# Name: RAM-GB, dtype: int64

# %%
new_table['RAM1']=new_table[1].str.replace('Flash','Flash Storage')

# %%
new_table
# Out:
#           0      1        2     3     4     5     6  RAM-GB           RAM1
# 0     128GB    SSD     None  None  None  None  None     128            SSD
# 1     128GB  Flash  Storage  None  None  None  None     128  Flash Storage
# 2     256GB    SSD     None  None  None  None  None     256            SSD
# 3     512GB    SSD     None  None  None  None  None     512            SSD
# 4     256GB    SSD     None  None  None  None  None     256            SSD
# ...     ...    ...      ...   ...   ...   ...   ...     ...            ...
# 1298  128GB    SSD     None  None  None  None  None     128            SSD
# 1299  512GB    SSD     None  None  None  None  None     512            SSD
# 1300   64GB  Flash  Storage  None  None  None  None      64  Flash Storage
# 1301    1TB    HDD     None  None  None  None  None      64            HDD
# 1302  500GB    HDD     None  None  None  None  None      64            HDD
#
# [1303 rows x 9 columns]

# %%
new_table[3].value_counts()
# Out:
#      207
# +      1
# Name: 3, dtype: int64

# %%
new_table[4].value_counts()
# Out:
# 1TB      184
# 2TB       15
# 256GB      3
# 500GB      2
# 1.0TB      2
# 512GB      1
#            1
# Name: 4, dtype: int64

# %%
new_table['RAM-GB2']=(
    new_table[4]
    .str.strip('TB')
    .str.strip('GB')
    .str.strip('.0')
    .str.strip('')
)

# %%
new_table['RAM-GB2'].value_counts()
# Out:
# 1      186
# 2       15
# 256      3
# 5        2
# 512      1
#          1
# Name: RAM-GB2, dtype: int64

# %%
new_table['RAM-GB2']=new_table['RAM-GB2'].str.replace(new_table['RAM-GB2'].unique()[6],'1')

# %%
new_table['RAM-GB2'].fillna(0,inplace=True)
new_table['RAM-GB2'] = new_table['RAM-GB2'].astype(int)
new_table['RAM-GB2'] = new_table['RAM-GB2'].replace([1,1000])
new_table['RAM-GB2'] = new_table['RAM-GB2'].replace([5,500])
new_table['RAM-GB2'] = new_table['RAM-GB2'].replace([2,2000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[200], line 3
#       1 new_table['RAM-GB2'].str.replace(new_table['RAM-GB2'].unique()[6],'1')
#       2 new_table['RAM-GB2'].fillna(0,inplace=True)
# ----> 3 new_table['RAM-GB2'] = new_table['RAM-GB2'].astype(int)
#       4 new_table['RAM-GB2'] = new_table['RAM-GB2'].replace([1,1000])
#       5 new_table['RAM-GB2'] = new_table['RAM-GB2'].replace([5,500])
#
# File /mnt/d/Projects/dataanalysis/lib/python3.8/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...
